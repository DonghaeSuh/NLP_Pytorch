# %% [markdown]
# <a href="https://colab.research.google.com/github/DonghaeSuh/NLP_Pytorch/blob/main/Preprocessing/TorchText_English.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #torchtext 설치 ( 버전을 맞춰야 torch.data의 Field 사용 가능 )

# %%
pip install torchtext==0.6
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchtext==0.6 in /usr/local/lib/python3.10/dist-packages (0.6.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6) (1.12.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6) (0.1.99)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6) (2.27.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6) (1.22.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6) (2022.12.7)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6) (4.5.0)

# %%
import urllib.request
import pandas as pd

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/LawrenceDuan/IMDb-Review-Analysis/master/IMDb_Reviews.csv", filename="IMDb_Reviews.csv")
# Out:
# ('IMDb_Reviews.csv', <http.client.HTTPMessage at 0x7f24835114e0>)

# %%
df=pd.read_csv('IMDb_Reviews.csv')
df.head()
# Out:
#                                               review  sentiment
# 0  My family and I normally do not watch local mo...          1
# 1  Believe it or not, this was at one time the wo...          0
# 2  After some internet surfing, I found the "Home...          0
# 3  One of the most unheralded great works of anim...          1
# 4  It was the Sixties, and anyone with long hair ...          0

# %%
len(df)
# Out:
# 50000

# %% [markdown]
# ## 데이터 훈련, 테스트 분리

# %%
from torchtext import data# torchtext.data 임포트

# %% [markdown]
# ## 필드 정의 ( 해당 값대로 데이터가 생성될 예정 )

# %%
TEXT = data.Field(sequential=True,
                  use_vocab=True,
                  tokenize=str.split,
                  lower=True,
                  batch_first=True,
                  fix_length=20)

LABEL = data.Field(sequential=False,
                   use_vocab=False,
                   batch_first=False,
                   is_target=True)

# %%
from torchtext.data import TabularDataset

# %%
dataset=TabularDataset(path='IMDb_Reviews.csv',format='CSV',fields=[('text',TEXT),('label',LABEL)],skip_header=True)

# %%
import random
SEED=123

# %%
train_data,test_data=dataset.split(split_ratio=0.8,stratified=True,strata_field='label',random_state=random.seed(SEED))

# %%
print('훈련 샘플의 개수 : {}'.format(len(train_data)))
print('테스트 샘플의 개수 : {}'.format(len(test_data)))
# Out:
# 훈련 샘플의 개수 : 40000
# 테스트 샘플의 개수 : 10000

# %% [markdown]
# ## 값 확인

# %%
print(vars(train_data[0]))
# Out:
# {'text': ['if', 'you', 'only', 'see', 'one', 'ernest', 'movie', 'in', 'your', 'life,', 'make', 'it', 'this', 'one!', 'this', 'is', 'by', 'far', 'the', 'best', 'in', 'the', 'series,', 'with', 'its', 'nonstop', 'laughs', 'and', 'clever', 'humor', 'that', 'is', 'suitable', 'for', 'all', 'ages.', 'the', 'other', '"ernest"', 'flicks', 'were', 'good', 'too,', 'but', 'most', 'people', 'tend', 'to', 'get', 'tired', 'of', 'him', 'quickly', '(not', 'me,', 'however.).<br', '/><br', '/>in', 'this', 'movie,', 'ernest', 'p.', 'whorrel', 'is', 'assigned', 'jury', 'duty', 'for', 'a', 'murder', 'case.', 'the', 'murderer,', 'nash,', 'just', 'happens', 'to', 'look', 'exactly', 'like', 'our', 'bumbling', 'hero', 'ernest.', 'mr.', 'nash', 'finds', 'this', 'a', 'good', 'opportunity', 'to', 'escape', 'from', 'jail', 'by', 'knocking', 'him', 'out', 'switching', 'identities', 'with', 'him,', 'and', 'so', 'we', 'get', 'to', 'see', 'how', 'ernest', 'reacts', 'in', 'the', 'slammer.<br', '/><br', '/>a', 'great', 'flick!', 'if', 'you', "haven't", 'already', 'seen', 'it,', 'watch', 'it!'], 'label': '1'}

# %%
print(train_data.fields.items())
# Out:
# dict_items([('text', <torchtext.data.field.Field object at 0x7f240b7d8b20>), ('label', <torchtext.data.field.Field object at 0x7f240b7da080>)])

# %% [markdown]
# # 단어 사전(Vocabulary) 만들기

# %%
TEXT.build_vocab(train_data, min_freq=10, max_size=10000) # min_freq : 최소 빈도 개수 , max_size : 단어 집합의 최대 크기

# %%
print('단어 집합의 크기 : {}'.format(len(TEXT.vocab)))
# Out:
# 단어 집합의 크기 : 10002

# %%
print(TEXT.vocab.stoi) # <unk>와 <pad>가 붙어서 10002개가 된다. 문자열->index
# Out:
# defaultdict(<bound method Vocab._default_unk_index of <torchtext.vocab.Vocab object at 0x7f23deefbdf0>>, {'<unk>': 0, '<pad>': 1, 'the': 2, 'a': 3, 'and': 4, 'of': 5, 'to': 6, 'is': 7, 'in': 8, 'i': 9, 'this': 10, 'that': 11, 'it': 12, '/><br': 13, 'was': 14, 'as': 15, 'with': 16, 'for': 17, 'but': 18, 'on': 19, 'movie': 20, 'are': 21, 'his': 22, 'not': 23, 'film': 24, 'you': 25, 'have': 26, 'he': 27, 'be': 28, 'at': 29, 'one': 30, 'by': 31, 'an': 32, 'they': 33, 'from': 34, 'who': 35, 'all': 36, 'like': 37, 'so': 38, 'just': 39, 'or': 40, 'has': 41, 'about': 42, "it's": 43, 'her': 44, 'if': 45, 'some': 46, 'out': 47, 'what': 48, 'when': 49, 'very': 50, 'there': 51, 'more': 52, 'would': 53, 'even': 54, 'my': 55, 'she': 56, 'good': 57, 'only': 58, 'their': 59, 'no': 60, 'really': 61, 'had': 62, 'can': 63, 'up': 64, 'which': 65, 'see': 66, 'were': 67, 'than': 68, '-': 69, 'we': 70, 'been': 71, 'get': 72, 'will': 73, 'into': 74, 'much': 75, 'because': 76, 'story': 77, 'how': 78, 'most': 79, 'other': 80, "don't": 81, 'also': 82, 'its': 83, 'do': 84, 'time': 85, 'first': 86, 'great': 87, 'me': 88, 'people': 89, 'make': 90, 'could': 91, 'any': 92, '/>the': 93, 'after': 94, 'then': 95, 'made': 96, 'bad': 97, 'think': 98, 'many': 99, 'being': 100, 'him': 101, 'never': 102, 'two': 103, '<br': 104, 'too': 105, 'where': 106, 'little': 107, 'well': 108, 'watch': 109, 'your': 110, 'way': 111, 'it.': 112, 'did': 113, 'them': 114, 'love': 115, 'does': 116, 'know': 117, 'best': 118, 'movie.': 119, 'seen': 120, 'characters': 121, 'character': 122, 'these': 123, 'movies': 124, 'ever': 125, 'still': 126, 'films': 127, 'over': 128, 'plot': 129, 'show': 130, 'such': 131, 'should': 132, 'acting': 133, 'while': 134, 'those': 135, 'better': 136, 'off': 137, 'film.': 138, 'go': 139, 'say': 140, 'something': 141, 'through': 142, 'why': 143, "doesn't": 144, "didn't": 145, "i'm": 146, 'scene': 147, 'film,': 148, 'makes': 149, 'watching': 150, 'movie,': 151, 'find': 152, 'real': 153, 'back': 154, 'scenes': 155, 'actually': 156, 'few': 157, 'every': 158, 'man': 159, 'life': 160, 'going': 161, '/>i': 162, 'new': 163, 'same': 164, 'look': 165, 'nothing': 166, 'another': 167, 'lot': 168, 'quite': 169, 'thing': 170, 'want': 171, '&': 172, 'end': 173, 'old': 174, 'seems': 175, 'got': 176, 'pretty': 177, "can't": 178, 'before': 179, 'take': 180, 'actors': 181, 'years': 182, 'part': 183, 'give': 184, 'may': 185, 'young': 186, 'between': 187, "that's": 188, 'us': 189, 'big': 190, 'both': 191, "i've": 192, 'without': 193, 'things': 194, 'thought': 195, 'gets': 196, 'around': 197, 'almost': 198, 'must': 199, 'though': 200, "isn't": 201, 'now': 202, 'it,': 203, 'saw': 204, 'director': 205, 'here': 206, 'always': 207, 'horror': 208, 'whole': 209, 'work': 210, 'come': 211, 'own': 212, 'down': 213, 'might': 214, "there's": 215, '"the': 216, 'cast': 217, 'am': 218, "he's": 219, 'enough': 220, 'least': 221, 'bit': 222, 'probably': 223, 'last': 224, 'since': 225, 'long': 226, 'far': 227, 'feel': 228, 'rather': 229, 'funny': 230, 'kind': 231, 'each': 232, 'fact': 233, 'found': 234, 'original': 235, 'our': 236, 'world': 237, 'worst': 238, 'guy': 239, 'trying': 240, 'anything': 241, 'done': 242, 'having': 243, 'making': 244, 'interesting': 245, 'action': 246, 'comes': 247, 'right': 248, 'however,': 249, 'put': 250, 'anyone': 251, 'believe': 252, 'point': 253, 'music': 254, '/>this': 255, 'main': 256, 'goes': 257, 'played': 258, 'worth': 259, 'role': 260, 'hard': 261, 'looking': 262, 'looks': 263, 'especially': 264, 'yet': 265, "wasn't": 266, 'watched': 267, 'series': 268, 'tv': 269, 'during': 270, 'minutes': 271, 'performance': 272, 'plays': 273, 'takes': 274, 'sure': 275, 'family': 276, 'seem': 277, 'three': 278, 'someone': 279, 'script': 280, 'different': 281, 'shows': 282, 'maybe': 283, 'everything': 284, 'away': 285, 'although': 286, 'comedy': 287, 'woman': 288, 'times': 289, 'set': 290, 'time.': 291, 'girl': 292, 'left': 293, 'american': 294, 'seeing': 295, 'once': 296,  ...

# %%
print(TEXT.vocab.itos) # index->문자열
print(TEXT.vocab.itos[14])
print(TEXT.vocab.itos[194])
print(TEXT.vocab.itos[237])
# Out:
# ['<unk>', '<pad>', 'the', 'a', 'and', 'of', 'to', 'is', 'in', 'i', 'this', 'that', 'it', '/><br', 'was', 'as', 'with', 'for', 'but', 'on', 'movie', 'are', 'his', 'not', 'film', 'you', 'have', 'he', 'be', 'at', 'one', 'by', 'an', 'they', 'from', 'who', 'all', 'like', 'so', 'just', 'or', 'has', 'about', "it's", 'her', 'if', 'some', 'out', 'what', 'when', 'very', 'there', 'more', 'would', 'even', 'my', 'she', 'good', 'only', 'their', 'no', 'really', 'had', 'can', 'up', 'which', 'see', 'were', 'than', '-', 'we', 'been', 'get', 'will', 'into', 'much', 'because', 'story', 'how', 'most', 'other', "don't", 'also', 'its', 'do', 'time', 'first', 'great', 'me', 'people', 'make', 'could', 'any', '/>the', 'after', 'then', 'made', 'bad', 'think', 'many', 'being', 'him', 'never', 'two', '<br', 'too', 'where', 'little', 'well', 'watch', 'your', 'way', 'it.', 'did', 'them', 'love', 'does', 'know', 'best', 'movie.', 'seen', 'characters', 'character', 'these', 'movies', 'ever', 'still', 'films', 'over', 'plot', 'show', 'such', 'should', 'acting', 'while', 'those', 'better', 'off', 'film.', 'go', 'say', 'something', 'through', 'why', "doesn't", "didn't", "i'm", 'scene', 'film,', 'makes', 'watching', 'movie,', 'find', 'real', 'back', 'scenes', 'actually', 'few', 'every', 'man', 'life', 'going', '/>i', 'new', 'same', 'look', 'nothing', 'another', 'lot', 'quite', 'thing', 'want', '&', 'end', 'old', 'seems', 'got', 'pretty', "can't", 'before', 'take', 'actors', 'years', 'part', 'give', 'may', 'young', 'between', "that's", 'us', 'big', 'both', "i've", 'without', 'things', 'thought', 'gets', 'around', 'almost', 'must', 'though', "isn't", 'now', 'it,', 'saw', 'director', 'here', 'always', 'horror', 'whole', 'work', 'come', 'own', 'down', 'might', "there's", '"the', 'cast', 'am', "he's", 'enough', 'least', 'bit', 'probably', 'last', 'since', 'long', 'far', 'feel', 'rather', 'funny', 'kind', 'each', 'fact', 'found', 'original', 'our', 'world', 'worst', 'guy', 'trying', 'anything', 'done', 'having', 'making', 'interesting', 'action', 'comes', 'right', 'however,', 'put', 'anyone', 'believe', 'point', 'music', '/>this', 'main', 'goes', 'played', 'worth', 'role', 'hard', 'looking', 'looks', 'especially', 'yet', "wasn't", 'watched', 'series', 'tv', 'during', 'minutes', 'performance', 'plays', 'takes', 'sure', 'family', 'seem', 'three', 'someone', 'script', 'different', 'shows', 'maybe', 'everything', 'away', 'although', 'comedy', 'woman', 'times', 'set', 'time.', 'girl', 'left', 'american', 'seeing', 'once', 'special', "you're", 'simply', 'play', 'completely', 'everyone', 'used', 'fun', 'again', 'well,', 'reason', 'john', 'read', 'true', 'high', 'given', 'need', 'black', 'truly', 'dvd', 'sense', '--', 'until', 'use', 'idea', 'beautiful', 'nice', 'try', 'ending', 'recommend', 'job', 'getting', 'place', 'along', 'came', 'let', 'help', 'shot', 'rest', 'poor', 'version', 'keep', 'excellent', 'couple', 'half', 'second', 'tell', 'less', 'full', 'effects', 'money', 'instead', 'enjoy', 'gives', 'actor', 'said', 'day', 'playing', 'fan', '(and', 'understand', 'audience', 'book', "couldn't", 'definitely', 'absolutely', 'himself', 'went', 'next', 'early', 'small', 'together', 'entire', 'become', 'supposed', 'short', 'remember', 'all,', 'start', 'war', 'screen', '2', 'doing', 'human', 'later', 'several', 'certainly', 'hollywood', 'perhaps', 'loved', 'liked', 'felt', 'sort', 'against', 'men', '(the', 'kids', 'star', 'totally', 'often', 'year', 'wife', 'seemed', 'piece', 'is,', 'production', 'camera', 'night', 'hope', 'time,', 'top', 'wonderful', '10', 'else', 'waste', 'becomes', 'wanted', 'able', "she's", '.', 'course', "you'll", 'classic', 'video', 'friends', 'final', 'home', 'line', 'that,', 'death', 'based', 'called', 'live', 'them.', 'house', '\x96', 'school', 'women', 'performances', 'mind', 'name', 'father', 'stupid', 'lost', 'already', "i'd", 'despite', 'perfect', 'wants', "they're", 'one.', 'tries', 'gave', 'person', 'sex', 'under', 'sound', 'this,', 'low', 'enjoyed ...
# was
# things
# world

# %% [markdown]
# # DataLoader 만들기

# %%
from torchtext.data import Iterator

# %%
batch_size = 5

# %%
train_loader = Iterator(dataset=train_data, batch_size = batch_size)
test_loader = Iterator(dataset=test_data, batch_size = batch_size)

# %%
'''
device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

BATCH_SIZE = 32

train_iterator, test_iterator = data.BucketIterator.splits(
    (train_data, test_data),     # dataset
    sort=False,
    repeat=False,
    batch_size=BATCH_SIZE,       # 배치사이즈
    device=device)               # device 지정
'''
# Out:
# "\ndevice = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')\n\nBATCH_SIZE = 32\n\ntrain_iterator, test_iterator = data.BucketIterator.splits(\n    (train_data, test_data),     # dataset\n    sort=False,\n    repeat=False,\n    batch_size=BATCH_SIZE,       # 배치사이즈\n    device=device)               # device 지정\n"

# %%
print('훈련 데이터의 미니 배치 수 : {}'.format(len(train_loader)))
print('테스트 데이터의 미니 배치 수 : {}'.format(len(test_loader)))
# Out:
# 훈련 데이터의 미니 배치 수 : 8000
# 테스트 데이터의 미니 배치 수 : 2000

# %%
batch = next(iter(train_loader))

# %%
print(type(batch))
# Out:
# <class 'torchtext.data.batch.Batch'>

# %%
print(batch.text)
# Out:
# tensor([[  10,   24,   14,   30,   11,    9,   26, 5031,    6,   66,   17,   46,
#           291,    9,   14, 1163,    6,  152,   12,   41],
#         [ 618,  192,  309,   36,    5,    2,  857, 6241,  206,    4, 1064,   16,
#             2,   99, 1307, 4736,   18,  395, 3919,   16],
#         [   9,   61,  195,   33,  113,   32,    0, 2294,   51,   14,  166,  526,
#            16,   12,   29,  374,    9,   81,  117,   78],
#         [ 245,  321,    4, 1031,   65,  145,  169, 4090,   13, 1788,   25,   66,
#             2,  148,  283,   25,   73,  228,   15,    0],
#         [   9,  867,   10,   94,   39,  295,    2, 2332,  476, 4694,    8,    2,
#             0,    4,    6,   88,   12,  199,   28,    3]])
